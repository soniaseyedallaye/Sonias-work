# %%
import pandas as pd 
from matplotlib import pyplot as plt 
import numpy as np 
import utils
import matplotlib 


np.random.seed(1000)
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [16, 4]

# %%
data = pd.read_csv('data/bitcoin.csv')

# %%
data.head(n=3)
# Out:
#              Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 0  2017-01-01 00:00:00  973.37  973.37  973.35  973.35      2.122048
# 1  2017-01-01 00:01:00  973.37  973.37  973.35  973.35      2.122048
# 2  2017-01-01 00:02:00  973.37  973.37  973.35  973.35      2.122048
#
#    Volume_(Currency)  Weighted_Price
# 0        2065.524303      973.363509
# 1        2065.524303      973.363509
# 2        2065.524303      973.363509

# %%
time_as_timestamp = pd.to_datetime(data.Timestamp,infer_datetime_format = True)

# %%
time_as_timestamp
# Out:
# 0        2017-01-01 00:00:00
# 1        2017-01-01 00:01:00
# 2        2017-01-01 00:02:00
# 3        2017-01-01 00:03:00
# 4        2017-01-01 00:04:00
#                  ...
# 647996   2018-03-26 23:56:00
# 647997   2018-03-26 23:57:00
# 647998   2018-03-26 23:58:00
# 647999   2018-03-26 23:59:00
# 648000   2018-03-27 00:00:00
# Name: Timestamp, Length: 648001, dtype: datetime64[ns]

# %%
data['time_as_timestamp'] = time_as_timestamp

# %%
data1 = data.copy()

# %%
data1.head()
# Out:
#              Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 0  2017-01-01 00:00:00  973.37  973.37  973.35  973.35      2.122048
# 1  2017-01-01 00:01:00  973.37  973.37  973.35  973.35      2.122048
# 2  2017-01-01 00:02:00  973.37  973.37  973.35  973.35      2.122048
# 3  2017-01-01 00:03:00  973.36  973.36  973.36  973.36      0.040000
# 4  2017-01-01 00:04:00  973.36  973.40  973.36  973.39      5.458800
#
#    Volume_(Currency)  Weighted_Price   time_as_timestamp
# 0        2065.524303      973.363509 2017-01-01 00:00:00
# 1        2065.524303      973.363509 2017-01-01 00:01:00
# 2        2065.524303      973.363509 2017-01-01 00:02:00
# 3          38.934400      973.360000 2017-01-01 00:03:00
# 4        5313.529708      973.387871 2017-01-01 00:04:00

# %%
data1 = data1.drop('Timestamp',axis =1)

# %%
data1
# Out:
#            Open     High      Low    Close  Volume_(BTC)  Volume_(Currency)  \
# 0        973.37   973.37   973.35   973.35      2.122048        2065.524303
# 1        973.37   973.37   973.35   973.35      2.122048        2065.524303
# 2        973.37   973.37   973.35   973.35      2.122048        2065.524303
# 3        973.36   973.36   973.36   973.36      0.040000          38.934400
# 4        973.36   973.40   973.36   973.39      5.458800        5313.529708
# ...         ...      ...      ...      ...           ...                ...
# 647996  8155.00  8155.00  8154.99  8154.99      0.617945        5039.342643
# 647997  8154.99  8154.99  8154.00  8154.01     40.655410      331543.193980
# 647998  8154.00  8154.01  8150.00  8150.00      9.856911       80340.432933
# 647999  8150.01  8150.01  8122.82  8145.00     68.274269      555026.852280
# 648000  8144.99  8145.01  8140.00  8140.00     37.842674      308202.442620
#
#         Weighted_Price   time_as_timestamp
# ...

# %%
data1['year'] = data1['time_as_timestamp'].dt.year
data1['month'] = data1['time_as_timestamp'].dt.month
data1['day'] = data1['time_as_timestamp'].dt.day
data1['hour'] = data1['time_as_timestamp'].dt.hour
data1['minute'] = data1['time_as_timestamp'].dt.minute
data1['second'] = data1['time_as_timestamp'].dt.second

# %% [markdown]
# #

# %%
data1
# Out:
#            Open     High      Low    Close  Volume_(BTC)  Volume_(Currency)  \
# 0        973.37   973.37   973.35   973.35      2.122048        2065.524303
# 1        973.37   973.37   973.35   973.35      2.122048        2065.524303
# 2        973.37   973.37   973.35   973.35      2.122048        2065.524303
# 3        973.36   973.36   973.36   973.36      0.040000          38.934400
# 4        973.36   973.40   973.36   973.39      5.458800        5313.529708
# ...         ...      ...      ...      ...           ...                ...
# 647996  8155.00  8155.00  8154.99  8154.99      0.617945        5039.342643
# 647997  8154.99  8154.99  8154.00  8154.01     40.655410      331543.193980
# 647998  8154.00  8154.01  8150.00  8150.00      9.856911       80340.432933
# 647999  8150.01  8150.01  8122.82  8145.00     68.274269      555026.852280
# 648000  8144.99  8145.01  8140.00  8140.00     37.842674      308202.442620
#
# ...

# %%
data1.time_as_timestamp
# Out:
# 0        2017-01-01 00:00:00
# 1        2017-01-01 00:01:00
# 2        2017-01-01 00:02:00
# 3        2017-01-01 00:03:00
# 4        2017-01-01 00:04:00
#                  ...
# 647996   2018-03-26 23:56:00
# 647997   2018-03-26 23:57:00
# 647998   2018-03-26 23:58:00
# 647999   2018-03-26 23:59:00
# 648000   2018-03-27 00:00:00
# Name: time_as_timestamp, Length: 648001, dtype: datetime64[ns]

# %%
pd.date_range()
