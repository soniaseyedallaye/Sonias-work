# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/online_orders.csv")

# %%
data.head(n=5)
# Out:
#      country        date    sales  n_items  n_orders  day_of_week
# 0  Australia  2010-12-01   358.25      107         1            2
# 1  Australia  2010-12-08   258.90      214         1            2
# 2  Australia  2010-12-17   415.70      146         1            4
# 3  Australia  2011-01-06  7154.38     4802         2            3
# 4  Australia  2011-01-10    81.60       96         1            0

# %%
data.describe()
# Out:
#               sales       n_items    n_orders  day_of_week
# count    967.000000    967.000000  967.000000   967.000000
# mean    1408.645698    797.897622    1.684592     2.460186
# std     2604.218572   1676.120131    1.126934     1.714696
# min        4.950000      1.000000    1.000000     0.000000
# 25%      350.140000    166.000000    1.000000     1.000000
# 50%      683.930000    346.000000    1.000000     2.000000
# 75%     1303.340000    700.000000    2.000000     4.000000
# max    25833.560000  18140.000000   10.000000     6.000000

# %%
data.plot.scatter(x = 'n_items', y = 'sales');

# %%
plt.rcParams["figure.figsize"]= [14,14]

# %%
data.plot.scatter(x = 'n_items',y='sales');

# %%
# %matplotlib notebook

# %%
data.plot(x = 'n_items',y = 'sales', kind = 'scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data
# Out:
#          country        date    sales  n_items  n_orders  day_of_week
# 0      Australia  2010-12-01   358.25      107         1            2
# 1      Australia  2010-12-08   258.90      214         1            2
# 2      Australia  2010-12-17   415.70      146         1            4
# 3      Australia  2011-01-06  7154.38     4802         2            3
# 4      Australia  2011-01-10    81.60       96         1            0
# ..           ...         ...      ...      ...       ...          ...
# 962  Switzerland  2011-11-06  6207.67     2708         1            6
# 963  Switzerland  2011-11-11   292.58       64         1            4
# 964  Switzerland  2011-11-18   925.64      669         1            4
# 965  Switzerland  2011-11-23   430.57      185         2            2
# 966  Switzerland  2011-11-29   262.50      151         1            1
#
# [967 rows x 6 columns]

# %%
data[data.country == 'Germany'].plot(x='date',y='sales',label='Germany');
data[data.country == 'France'].set_index('date').sales.plot(label='France');
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
