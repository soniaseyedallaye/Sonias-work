# %%
linear_regression = lambda x,b_0,b_1:b_0 + b_1*x

# %%
linear_regression(0.5,1,2)
# Out:
# 2.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sns

# %%
xlim = (-12,12)
ylim = (-25,25)
origin = (0,0)
plt.plot(origin,ylim, 'g:',linewidth=0.4);
xl = np.arange(-10,10)
plt.plot(xl,linear_regression(xl,2,1),'rp')

# %%
df = pd.read_csv('data/linear-learning-notebook.csv')
df
# Out:
#            x         y
# 0  -3.325653  4.930689
# 1  -5.208228  5.155557
# 2  -4.224491  3.764528
# 3  -4.000666  4.424947
# 4  -5.858069  5.782441
# 5  -4.746939  5.369360
# 6  -1.637624  2.857682
# 7  -3.715092  2.708166
# 8  -0.958962  1.854310
# 9  -4.486578  5.597853
# 10 -3.756787  2.651134
# 11 -4.897145  5.735623
# 12 -2.601579  2.172063
# 13 -1.205497  0.660198
# 14 -0.844179  0.152183
# 15 -2.165614  1.799569
# 16 -0.179956 -1.037285
# 17 -1.786767  2.051869
# 18 -3.892760  3.742043
# 19 -1.058480  1.894160
# 20 -0.789618  1.984780
# 21  0.186539 -0.958279
# 22 -0.713084  0.918777
# 23  1.945663 -3.290651
# 24  1.519017 -2.617375
# 25 -2.452829  1.219302
# 26 -1.079850  0.012567
# 27 -0.766829 -0.937381
# 28  0.313628  0.149787
# 29  3.212859 -2.579857
# 30 -0.028322 -0.431257
# 31 -0.515302  1.210190
# 32  3.323418 -4.483904
# 33  0.636855 -1.397058
# 34  0.423098 -1.209641
# 35  3.438044 -5.290430
# 36  4.527903 -4.845519
# 37  3.305626 -4.427746
# 38  2.516853 -3.124890
# ...

# %%
plt.plot(df['x'].values,df['y'].values,'r.')

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
from ipywidgets import FloatSlider, Dropdown
import ipywidgets as widgets

# %%
def greeting(text="World"):
        print("Hello {}".format(text))
interact(greeting, text="IPython Widgets")
# Out:
# interactive(children=(Text(value='IPython Widgets', description='text'), Output()), _dom_classes=('widget-inte…
# <function __main__.greeting(text='World')>

# %%
a= [1,2,3]
b=np.transpose([1,2,3])
np.matmul(b,a)
# Out:
# 14

# %%
multiple_linear_regresion = lambda x,betas:betas[0]+np.matmul(x,betas[1:])

# %%
np.arange(-10, 10, 0.1).reshape(-1, 1)
# Out:
# array([[-1.00000000e+01],
#        [-9.90000000e+00],
#        [-9.80000000e+00],
#        [-9.70000000e+00],
#        [-9.60000000e+00],
#        [-9.50000000e+00],
#        [-9.40000000e+00],
#        [-9.30000000e+00],
#        [-9.20000000e+00],
#        [-9.10000000e+00],
#        [-9.00000000e+00],
#        [-8.90000000e+00],
#        [-8.80000000e+00],
#        [-8.70000000e+00],
#        [-8.60000000e+00],
#        [-8.50000000e+00],
#        [-8.40000000e+00],
#        [-8.30000000e+00],
#        [-8.20000000e+00],
#        [-8.10000000e+00],
#        [-8.00000000e+00],
#        [-7.90000000e+00],
#        [-7.80000000e+00],
#        [-7.70000000e+00],
#        [-7.60000000e+00],
#        [-7.50000000e+00],
#        [-7.40000000e+00],
#        [-7.30000000e+00],
#        [-7.20000000e+00],
#        [-7.10000000e+00],
#        [-7.00000000e+00],
#        [-6.90000000e+00],
#        [-6.80000000e+00],
#        [-6.70000000e+00],
#        [-6.60000000e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
df_salary = pd.read_csv('data/salary_data.csv')
df_salary.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df_salary.YearsExperience.values
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])
