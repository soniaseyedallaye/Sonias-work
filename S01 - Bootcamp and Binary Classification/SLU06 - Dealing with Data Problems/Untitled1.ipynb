# %%
import os
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_messy = pd.read_csv(os.path.join('data', 'column_headers_are_values.csv'), sep=' ')
df_messy
# Out:
#                   religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k
# 0                 Agnostic     27       34       60       81       76      137
# 1                  Atheist     12       27       37       52       35       70
# 2                 Buddhist     27       21       30       34       33       58
# 3                 Catholic    418      617      732      670      638     1116
# 4       Don’t know/refused     15       14       15       11       10       35
# 5         Evangelical Prot    575      869     1064      982      881     1486
# 6                    Hindu      1        9        7        9       11       34
# 7  Historically Black Prot    228      244      236      238      197      223
# 8        Jehovah’s Witness     20       27       24       24       21       30
# 9                   Jewish     19       19       25       25       30       95

# %%
cl = df_messy.columns.to_list()
del cl[0]
cl
# Out:
# ['<$10k', '$10-20k', '$20-30k', '$30-40k', '$40-50k', '$50-75k']

# %%
df_messy.loc[df_messy.religion=='Buddhist',['$10-20k','$20-30k','$30-40k']].sum(axis =1).values[0]
# Out:
# 85

# %%
df_messy
# Out:
#                   religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k
# 0                 Agnostic     27       34       60       81       76      137
# 1                  Atheist     12       27       37       52       35       70
# 2                 Buddhist     27       21       30       34       33       58
# 3                 Catholic    418      617      732      670      638     1116
# 4       Don’t know/refused     15       14       15       11       10       35
# 5         Evangelical Prot    575      869     1064      982      881     1486
# 6                    Hindu      1        9        7        9       11       34
# 7  Historically Black Prot    228      244      236      238      197      223
# 8        Jehovah’s Witness     20       27       24       24       21       30
# 9                   Jewish     19       19       25       25       30       95

# %%
df_tidy = df_messy.copy()

# %%
df_tidy = df_tidy[['religion']]

# %%
df_tidy['income'] = 0

# %%
df_tidy
# Out:
#                   religion  income
# 0                 Agnostic       0
# 1                  Atheist       0
# 2                 Buddhist       0
# 3                 Catholic       0
# 4       Don’t know/refused       0
# 5         Evangelical Prot       0
# 6                    Hindu       0
# 7  Historically Black Prot       0
# 8        Jehovah’s Witness       0
# 9                   Jewish       0

# %%
income_values = list(filter(lambda x: x != 'religion', df_messy.columns.tolist()))
print(f"Income values stored in the columns:\n{income_values}")
# Out:
# Income values stored in the columns:
# ['<$10k', '$10-20k', '$20-30k', '$30-40k', '$40-50k', '$50-75k']

# %%
df_n_contracts = pd.read_csv(os.path.join('data', 'n_renting_contracts.csv'), index_col=0)
df_n_contracts.head()
# Out:
#           MADRID    rome    Rome  Lisboa  madrid   Roma  Budapest   paris  \
# dec          NaN     NaN   540.0   186.0  1235.0    NaN     994.0   417.0
# APRIL      198.0  1133.0   975.0  1192.0     NaN    NaN       NaN  1157.0
# jun         96.0     NaN  1277.0   937.0  1324.0  542.0       NaN     NaN
# november     NaN     NaN    62.0     NaN     NaN    NaN       NaN   474.0
# January      NaN   652.0     NaN     NaN   674.0    NaN     938.0   432.0
#
#           Lisbon  LISBON  Barcelona   Milan  BERLIN  budapest  \
# dec       1420.0     NaN      401.0  1045.0  1085.0       NaN
# APRIL      261.0    34.0        NaN     NaN  1081.0     510.0
# jun        502.0     NaN     1147.0   638.0  1093.0       NaN
# november  1486.0   887.0      607.0  1201.0   470.0       NaN
# January    371.0     NaN        NaN     NaN  1233.0       NaN
#
#           lisbon, Portugal  paris, france
# dec                 1340.0          865.0
# APRIL                571.0            NaN
# ...

# %%
df_n_contracts.reset_index().rename(columns = {'index':'new_name'})
# Out:
#      new_name  MADRID    rome    Rome  Lisboa  madrid    Roma  Budapest  \
# 0         dec     NaN     NaN   540.0   186.0  1235.0     NaN     994.0
# 1       APRIL   198.0  1133.0   975.0  1192.0     NaN     NaN       NaN
# 2         jun    96.0     NaN  1277.0   937.0  1324.0   542.0       NaN
# 3    november     NaN     NaN    62.0     NaN     NaN     NaN       NaN
# 4     January     NaN   652.0     NaN     NaN   674.0     NaN     938.0
# 5       April   380.0  1496.0     NaN   254.0     NaN   229.0      97.0
# 6         May  1247.0   249.0     NaN     NaN     NaN     NaN     978.0
# 7     OCTOBER   599.0     NaN  1026.0     NaN   746.0   344.0    1372.0
# 8     October     NaN    56.0     NaN   836.0   723.0   815.0       NaN
# 9       MARCH     NaN   203.0   588.0     NaN     NaN    60.0     855.0
# 10        Jul   796.0     NaN     NaN  1087.0     NaN   307.0     447.0
# 11     August  1000.0     NaN   175.0   547.0  1091.0  1096.0       NaN
# ...

# %%
df_n_contracts = pd.read_csv(os.path.join('data', 'n_renting_contracts.csv'), index_col=0)
df_n_contracts
# Out:
#            MADRID    rome    Rome  Lisboa  madrid    Roma  Budapest   paris  \
# dec           NaN     NaN   540.0   186.0  1235.0     NaN     994.0   417.0
# APRIL       198.0  1133.0   975.0  1192.0     NaN     NaN       NaN  1157.0
# jun          96.0     NaN  1277.0   937.0  1324.0   542.0       NaN     NaN
# november      NaN     NaN    62.0     NaN     NaN     NaN       NaN   474.0
# January       NaN   652.0     NaN     NaN   674.0     NaN     938.0   432.0
# April       380.0  1496.0     NaN   254.0     NaN   229.0      97.0  1269.0
# May        1247.0   249.0     NaN     NaN     NaN     NaN     978.0   547.0
# OCTOBER     599.0     NaN  1026.0     NaN   746.0   344.0    1372.0     NaN
# October       NaN    56.0     NaN   836.0   723.0   815.0       NaN     NaN
# MARCH         NaN   203.0   588.0     NaN     NaN    60.0     855.0   222.0
# Jul         796.0     NaN     NaN  1087.0     NaN   307.0     447.0     NaN
# ...

# %%
df_n_contracts.index.value_counts()
# Out:
# MARCH        1
# September    1
# APRIL        1
# november     1
# OCTOBER      1
# dec          1
# August       1
# October      1
# April        1
# JAN          1
# Jul          1
# June         1
# JANUARY      1
# January      1
# March        1
# Feb.         1
# July         1
# May          1
# DECEMBER     1
# February     1
# jun          1
# dtype: int64

# %%
df_n_contracts = df_n_contracts.reset_index().rename(columns = {'index':'Monthes'})
df_n_contracts
# Out:
#       Monthes  MADRID    rome    Rome  Lisboa  madrid    Roma  Budapest  \
# 0         dec     NaN     NaN   540.0   186.0  1235.0     NaN     994.0
# 1       APRIL   198.0  1133.0   975.0  1192.0     NaN     NaN       NaN
# 2         jun    96.0     NaN  1277.0   937.0  1324.0   542.0       NaN
# 3    november     NaN     NaN    62.0     NaN     NaN     NaN       NaN
# 4     January     NaN   652.0     NaN     NaN   674.0     NaN     938.0
# 5       April   380.0  1496.0     NaN   254.0     NaN   229.0      97.0
# 6         May  1247.0   249.0     NaN     NaN     NaN     NaN     978.0
# 7     OCTOBER   599.0     NaN  1026.0     NaN   746.0   344.0    1372.0
# 8     October     NaN    56.0     NaN   836.0   723.0   815.0       NaN
# 9       MARCH     NaN   203.0   588.0     NaN     NaN    60.0     855.0
# 10        Jul   796.0     NaN     NaN  1087.0     NaN   307.0     447.0
# 11     August  1000.0     NaN   175.0   547.0  1091.0  1096.0       NaN
# ...

# %%
df_n_contracts['Monthes']= df_n_contracts.Monthes.str.lower()
df_n_contracts
# Out:
#       Monthes  MADRID    rome    Rome  Lisboa  madrid    Roma  Budapest  \
# 0         dec     NaN     NaN   540.0   186.0  1235.0     NaN     994.0
# 1       april   198.0  1133.0   975.0  1192.0     NaN     NaN       NaN
# 2         jun    96.0     NaN  1277.0   937.0  1324.0   542.0       NaN
# 3    november     NaN     NaN    62.0     NaN     NaN     NaN       NaN
# 4     january     NaN   652.0     NaN     NaN   674.0     NaN     938.0
# 5       april   380.0  1496.0     NaN   254.0     NaN   229.0      97.0
# 6         may  1247.0   249.0     NaN     NaN     NaN     NaN     978.0
# 7     october   599.0     NaN  1026.0     NaN   746.0   344.0    1372.0
# 8     october     NaN    56.0     NaN   836.0   723.0   815.0       NaN
# 9       march     NaN   203.0   588.0     NaN     NaN    60.0     855.0
# 10        jul   796.0     NaN     NaN  1087.0     NaN   307.0     447.0
# 11     august  1000.0     NaN   175.0   547.0  1091.0  1096.0       NaN
# ...

# %%
df_n_contracts.Monthes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           dec
# 1         april
# 2           jun
# 3      november
# 4       january
# 5         april
# 6           may
# 7       october
# 8       october
# 9         march
# 10          jul
# 11       august
# 12          jan
# 13         feb.
# 14         july
# 15     december
# 16        march
# 17      january
# 18     february
# 19    september
# 20         june
# Name: Monthes, dtype: object>

# %%
df_n_contracts.Monthes.str.strip()
# Out:
# 0           dec
# 1         april
# 2           jun
# 3      november
# 4       january
# 5         april
# 6           may
# 7       october
# 8       october
# 9         march
# 10          jul
# 11       august
# 12          jan
# 13         feb.
# 14         july
# 15     december
# 16        march
# 17      january
# 18     february
# 19    september
# 20         june
# Name: Monthes, dtype: object

# %%
df_n_contracts = df_n_contracts.Monthes.replace({'june':'jun','january': 'jan','july':'jul','february':'feb','feb.':'feb','december':'dec'})

# %%
df_n_contracts
# Out:
# 0           dec
# 1         april
# 2           jun
# 3      november
# 4           jan
# 5         april
# 6           may
# 7       october
# 8       october
# 9         march
# 10          jul
# 11       august
# 12          jan
# 13          feb
# 14          jul
# 15          dec
# 16        march
# 17          jan
# 18          feb
# 19    september
# 20          jun
# Name: Monthes, dtype: object
