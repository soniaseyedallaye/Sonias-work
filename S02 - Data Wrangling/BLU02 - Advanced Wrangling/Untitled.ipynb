# %%
import numpy as np
import pandas as pd
import os

from sklearn.datasets import load_iris

# %%
works = pd.read_csv('./data/works.csv')

# %%
works.head()
# Out:
#                                    GUID  ProgramID  WorkID  MovementID  \
# 0  38e072a7-8fc9-4f9a-8eac-3957905c0002       3853   52446         NaN
# 1  c7b2b95c-5e0b-431c-a340-5b37fc860b34       5178   52437         NaN
# 2  894e1a52-1ae5-4fa7-aec0-b99997555a37      10785   52364         1.0
# 3  34ec2c2b-3297-4716-9831-b538310462b7       5887   52434         NaN
# 4  610a4acc-94e4-4cd6-bdc1-8ad020edc7e9        305   52453         NaN
#
#               ComposerName                                        WorkTitle  \
# 0  Beethoven,  Ludwig  van                 SYMPHONY NO. 5 IN C MINOR, OP.67
# 1  Beethoven,  Ludwig  van  SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)
# 2  Beethoven,  Ludwig  van                                    EGMONT, OP.84
# 3  Beethoven,  Ludwig  van                 SYMPHONY NO. 2 IN D MAJOR, OP.36
# 4  Beethoven,  Ludwig  van                 SYMPHONY NO. 7 IN A MAJOR, OP.92
#
#    Movement        ConductorName Interval
# ...

# %%
works['comp1'],works['comp2'] = works['ComposerName'].str.split(',',2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-56b9d5b24b1c> in <module>
# ----> 1 works['comp1'],works['comp2'] = works['ComposerName'].str.split(',',2)
#
# ValueError: too many values to unpack (expected 2)

# %%
df.split()

# %%
    data = np.random.randn(6, 4)

# %%
data
# Out:
# array([[ 0.22889946, -0.12185992,  0.07709802, -0.86036779],
#        [ 0.61710616,  0.26875858, -0.70673672, -0.510798  ],
#        [-0.13393815, -0.3140338 , -1.37937659,  1.1239551 ],
#        [-1.46248944,  0.03563703, -1.57179817,  0.41399047],
#        [-0.43311857, -0.01474737,  2.89440848, -1.21378767],
#        [ 1.27670904, -0.11633033, -0.43509862,  0.7833399 ]])

# %%
def rename_column(df,new_column_name,old_column_name):
    df = df.copy()
    df[new_column_name] = df[old_column_name]
    df = df.drop(columns = old_column_name)
    return df

# %%
def rename_column(df, new_name, old_name):
    df = df.copy()
    df[new_name] = df[old_name]
    df = df.drop(columns=old_name)
    return df

# %%
rename_column(works,'aks','MovementID')
# Out:
#                                        GUID  ProgramID  WorkID  \
# 0      38e072a7-8fc9-4f9a-8eac-3957905c0002       3853   52446
# 1      c7b2b95c-5e0b-431c-a340-5b37fc860b34       5178   52437
# 2      894e1a52-1ae5-4fa7-aec0-b99997555a37      10785   52364
# 3      34ec2c2b-3297-4716-9831-b538310462b7       5887   52434
# 4      610a4acc-94e4-4cd6-bdc1-8ad020edc7e9        305   52453
# ...                                     ...        ...     ...
# 82571  734c1116-0caf-4f8b-80d0-5e423cd1bcc6       9678   53976
# 82572  884c64d6-1768-4cf1-85f1-0ac2f79bbe5c      10608   53976
# 82573  f549e93f-b35f-4824-b0d5-d543953535f8       9542   53976
# 82574  734c1116-0caf-4f8b-80d0-5e423cd1bcc6       9678   53976
# 82575  884c64d6-1768-4cf1-85f1-0ac2f79bbe5c      10608   53976
#
#                     ComposerName  \
# 0        Beethoven,  Ludwig  van
# 1        Beethoven,  Ludwig  van
# 2        Beethoven,  Ludwig  van
# 3        Beethoven,  Ludwig  van
# 4        Beethoven,  Ludwig  van
# ...
